# %% [markdown]
# ## 02-5 딕셔너리 자료형
#
# - 대응관계를 나타내는 자료형
# - 딕셔너리dictionary, 연관배열associative array, 해시hash

# %% [markdown]
# #### 딕셔너리
# - 사전, dictionary
# - Key와 Value를 한 쌍으로 하는 자료

# %% [markdown]
# ![image.png](attachment:0d71a05f-ce75-4321-97b3-abb529c67f8c.png)

# %% [markdown]
# {Key1: Value1, Key2: Value2, Key3: Value, ...}

# %%
dic = {'name': 'pey', 'phone': '010-2024-1234', 'birth': '1188'}

# %%
a = {1:'hi'}

# %%
a
# Out:
# {1: 'hi'}

# %%
a = {'a': [1,2,3,4]}

# %% [markdown]
# #### 딕셔너리 쌍 추가, 삭제하기

# %%
a
# Out:
# {'a': [1, 2, 3, 4]}

# %%
a['a']
# Out:
# [1, 2, 3, 4]

# %%
a['b'] = [1,3,4,5,]

# %%
a
# Out:
# {'a': [1, 2, 3, 4], 'b': [1, 3, 4, 5]}

# %%
del a['b']

# %%
a
# Out:
# {'a': [1, 2, 3, 4]}

# %% [markdown]
# #### 딕셔너리 사용법

# %%
dic['name']
# Out:
# 'pey'

# %%
dic['phone']
# Out:
# '010-2024-1234'

# %%
dic['birth']
# Out:
# '1188'

# %%
a = {1:'a', 1:'b'}

# %%
a
# Out:
# {1: 'b'}

# %%
a = {[1,2]:'b'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 a = {[1,2]:'b'}
#
# TypeError: unhashable type: 'list'

# %%
a = {(1,2):'b'}

# %%
a
# Out:
# {(1, 2): 'b'}

# %%
a[(1,2)]
# Out:
# 'b'

# %% [markdown]
# #### 딕셔너리 관련 함수

# %%
for k in dic.keys():
    print(k)
# Out:
# name
# phone
# birth

# %%
list(dic.keys())
# Out:
# ['name', 'phone', 'birth']

# %%
dic.values()
# Out:
# dict_values(['pey', '010-2024-1234', '1188'])

# %%
dic
# Out:
# {'name': 'pey', 'phone': '010-2024-1234', 'birth': '1188'}

# %%
dic.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '010-2024-1234'), ('birth', '1188')])

# %%
list(dic)
# Out:
# ['name', 'phone', 'birth']

# %%
list(dic.items())
# Out:
# [('name', 'pey'), ('phone', '010-2024-1234'), ('birth', '1188')]

# %%
b = list(dic.items())

# %%
b[1]
# Out:
# ('phone', '010-2024-1234')

# %%
for k in b:
    print(k)
# Out:
# ('name', 'pey')
# ('phone', '010-2024-1234')
# ('birth', '1188')

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
dic.get('name')
# Out:
# 'pey'

# %%
dic.get('address')

# %%
print(dic.get('address'))
# Out:
# None

# %%
dic['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 dic['address']
#
# KeyError: 'address'

# %%
dic.get('name', 'default_value')
# Out:
# 'pey'

# %%
dic.get('address', 'default_value')
# Out:
# 'default_value'

# %%
'name' in dic
# Out:
# True

# %%
'email' in dic
# Out:
# False
